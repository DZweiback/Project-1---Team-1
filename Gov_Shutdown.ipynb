# %% [markdown]
# # Project 1 - Team 1 Government Shutdown Project - Damita's Code

# %% [markdown]
# Search Tweets and Introduction to Cursors
# In this activity, let us see how to search through the Twitter universe for tweets that contain particular search terms.
#
# We will also learn about Cursors using Tweepy: http://docs.tweepy.org/en/latest/cursor_tutorial.html
#
# Please be mindful of Twitter Rate Limits! More information can be found here: https://developer.twitter.com/en/docs/basics/rate-limiting.html

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib

import tweepy
import json

from datetime import datetime
from pprint import pprint

# Import Twitter API Keys
#import sys
#sys.path.append('../../../..')
from djz_TwitterAPI import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
#api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())
api = tweepy.API(auth)

# %%
# !pip install vaderSentiment

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# # Search Government Shutdown Tweets using Pagination

# %%
# Remove the `parser=tweepy.parsers.JSONParser()` option when using Cursors
api = tweepy.API(auth)

# Set up variables
created_at = []
screen_name = [] 
user_name = [] 
full_text = [] 
favorite_count = []
hashtags = [] 

# Target User Account
target_tags = ["Government Shutdown", "Shutdown", "Border Wall", "The Wall"]


# Counter
counter = 1

for tag in target_tags:
    
    # 15 tweets per page (default), loop through 10 pages
    for page in tweepy.Cursor(api.search,
                                q=tag,
                                tweet_mode='extended').pages(10):
        
        for p in page:
            # page = page[0]
            tweet = json.dumps(p._json, indent=3)
            tweet = json.loads(tweet)

            tweet_created_at = datetime.strptime(tweet["created_at"], "%a %b %d %H:%M:%S %z %Y")        
            tweet_screen_name = tweet["user"]["screen_name"] 
            tweet_user_name = tweet["user"]["name"] 
            tweet_full_text = tweet["full_text"] 
            tweet_favorite_count = tweet["favorite_count"] 
            tweet_hashtags = tweet["entities"]["hashtags"] 

            created_at.append(tweet_created_at)
            screen_name.append(tweet_screen_name)
            user_name.append(tweet_user_name)
            full_text.append(tweet_full_text)
            favorite_count.append(tweet_favorite_count)
            hashtags.append(tweet_hashtags)

            # Print Tweets
            # Note: When using extended model, you need to pull out 'full_text' instead of 'text'
            # print(f'Tip {counter}: {tweet["full_text"]}')

            # Add to Counter
            counter = counter + 1

# %%
full_text
# Out:
# ['#FYI - #ChefsForFeds is looking to expand their reach &amp; help folks affected by the #GovernmentShutdown in other cities. https://t.co/LOPQO9TSjq',
#  "RT @SiriusXMPatriot: Missed @DonaldJTrumpJr 's Interview with @BreitbartNews Saturday?  Hear It Now.  #BuzzFeedNews #Buzzfeed #CNN #Governm…",
#  'RT @BLUEPRINT_Q: 1 - A short #GovernmentShutdown thread. Patriots are in control.\n\nEradication (30-day furlough mark)\nTruth (DECLAS)\nJustic…',
#  'RT @pollsofpolitics: Should @POTUS  @realDonaldTrump stop the #GovernmentShutdown,get government open and then make a #BorderSecurity deal…',
#  '@realDonaldTrump It’s already crashing with your unnecessary #GovernmentShutdown. You’re such a bull$hitter #GrifterInChief. Just quit please.',
#  'Literally make my government shut down, DADDY 😩🗝💯 #GovernmentShutdown #literallydaddy #DonaldTrump @DonaldTrumpll',
#  "#PUTIN'S #GOP WANTED #TRAITORTRUMP #FACISM RUNNING #AMERICA.  #TRUMP'S #LITERALLY A #RUSSIANSPY. #THANKS 2 #COLLUSION WE GOT #RIGHTWING #TERRORISM &amp; #GOVERNMENTSHUTDOWN #FEELTHEBERN #RESIST #HELP #END #CORPORATERULE OF #EARTH! #ITMFA #IMPEACH #MIKEPENCE IS JUST AS #EVIL AS #TRUMP https://t.co/cFxpWvghmQ",
#  '#realDonaldTrump the #Egyptian #pharaoh cried out like the #AmericanPharaohs for a wall to keep the #Jews in bondage like you seek to fence out the #Jewish #MigrantCaravan. HeGotIt! SEE?#TheTwoWitnesses #DACA #GovernmentShutdown #MichaelCohen #WomensMarch2019 #Dream11 #CNBC #CNN https://t.co/kaRh4zCGFC',
#  'RT @waywarddrift: Reducing our dependence on the economy is one of the most important things we can do in times like these\n#GovernmentShutd…',
#  "#PUTIN'S #GOP WANTED #TRAITORTRUMP #FACISM RUNNING #AMERICA.  #TRUMP'S #LITERALLY A #RUSSIANSPY. #THANKS 2 #COLLUSION WE GOT #RIGHTWING #TERRORISM &amp; #GOVERNMENTSHUTDOWN #FEELTHEBERN #RESIST #HELP #END #CORPORATERULE OF #EARTH! #ITMFA #IMPEACH #MIKEPENCE IS JUST AS #EVIL AS #TRUMP https://t.co/Yts8ENBKu4",
#  "RT @pj6969pj: #PUTIN'S #GOP WANTED #TRAITORTRUMP #FACISM RUNNING #AMERICA.  #TRUMP'S #LITERALLY A #RUSSIANSPY. #THANKS 2 #COLLUSION WE GOT…",
#  "#PUTIN'S #GOP WANTED #TRAITORTRUMP #FACISM RUNNING #AMERICA.  #TRUMP'S #LITERALLY A #RUSSIANSPY. #THANKS 2 #COLLUSION WE GOT #RIGHTWING #TERRORISM &amp; #GOVERNMENTSHUTDOWN #FEELTHEBERN #RESIST #HELP #END #CORPORATERULE OF #EARTH! #ITMFA #IMPEACH #MIKEPENCE IS JUST AS #EVIL AS #TRUMP https://t.co/ACSFbLlWWg",
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @sciencemagazine: The partial #GovernmentShutdown is now disrupting U.S. science agencies that aren’t closed. https://t.co/VnJAYAf3Dr',
#  "#PUTIN'S #GOP WANTED #TRAITORTRUMP #FACISM RUNNING #AMERICA.  #TRUMP'S #LITERALLY A #RUSSIANSPY. #THANKS 2 #COLLUSION WE GOT #RIGHTWING #TERRORISM &amp; #GOVERNMENTSHUTDOWN #FEELTHEBERN #RESIST #HELP #END #CORPORATERULE OF #EARTH! #ITMFA #IMPEACH #MIKEPENCE IS JUST AS #EVIL AS #TRUMP https://t.co/2Ns1vCXYqD",
#  "#PUTIN'S #GOP WANTED #TRAITORTRUMP #FACISM RUNNING #AMERICA.  #TRUMP'S #LITERALLY A #RUSSIANSPY. #THANKS 2 #COLLUSION WE GOT #RIGHTWING #TERRORISM &amp; #GOVERNMENTSHUTDOWN #FEELTHEBERN #RESIST #HELP #END #CORPORATERULE OF #EARTH! #ITMFA #IMPEACH #MIKEPENCE IS JUST AS #EVIL AS #TRUMP https://t.co/fbzgCQUzLH",
#  "RT @skiefer11: The #GovernmentShutdown is now in it's 28th day. That's a full menstrual cycle.",
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @threadreaderapp: @JenniferEvette6 Bonjour please find the unroll here: Thread by @BLUEPRINT_Q: "1 - A short thread. Patriots are in con…',
#  'RT @BLUEPRINT_Q: 12 - This concludes my short #GovernmentShutdown thread. Patriots are in control.\n\nEradication (30-day furlough mark)\nTrut…',
#  'RT @In_loso_wetrust: Due to the government shutdown aye guy name “Joe the Handyman Johnson” 😂😂😂made it so workers can report back to work s…',
#  '@realDonaldTrump aren’t you a billionaire? Why don’t you use your own money to build that wall.\nYou’re affecting real people’s livelihoods with this shut down!! #GovernmentShutdown',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  "#PUTIN'S #GOP WANTED #TRAITORTRUMP #FACISM RUNNING #AMERICA.  #TRUMP'S #LITERALLY A #RUSSIANSPY. #THANKS 2 #COLLUSION WE GOT #RIGHTWING #TERRORISM &amp; #GOVERNMENTSHUTDOWN #FEELTHEBERN #RESIST #HELP #END #CORPORATERULE OF #EARTH! #ITMFA #IMPEACH #MIKEPENCE IS JUST AS #EVIL AS #TRUMP https://t.co/MZLP72mTr1",
#  'RT @FreedomWorks: President Trump has created more jobs in the private sector than the furloughed federal workforce. \n\nThe #GovernmentShutd…',
#  'RT @GraceTheNurse: Another reason why the #GovernmentShutdown needs to end. #governmentemployees are being affected by #healthcare costs ht…',
#  'RT @FreedomWorks: President Trump has created more jobs in the private sector than the furloughed federal workforce. \n\nThe #GovernmentShutd…',
#  'RT @JohnBerryDC: IRS workers forced back to work without pay. Morale is probably not high. #GovernmentShutdown #IRS #FederalEmployees https…',
#  '@charliekirk11 and we have learned thanks to @JudicialWatch that the #DACA recipients did not go through the background checks we were promised\n\n#GovernmentShutdown \n#BuildTheDamnWallNow',
#  'RT @JohnBerryDC: #USCG military personnel beginning to stress over loss of paycheck &amp; inability to pay for family expenses. This must be fi…',
#  "President Trump has created more jobs in the private sector than the furloughed federal workforce. \n\nThe #GovernmentShutdown is an opportunity to strip wasteful agencies for good! \n\nThey're fighting for relevance but they will lose! End the abuse! #ampFW https://t.co/MlRiAlpo2I",
#  "RT @100isNow: From national parks to marine animals, here's a look at some of the key impacts of the shutdown that relate to the environmen…",
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @timsandle: U.S. government shutdown: Websites insecure and inaccessible https://t.co/ZStTDNkXYT #ShutdownStories #GovernmentShutdown #U…',
#  "RT @amjoyshow: .@DrJasonJohnson: Dems are just as dug in on this issue as Republicans. Pelosi's popularity has gone up since this happened.…",
#  'RT @BLUEPRINT_Q: 12 - This concludes my short #GovernmentShutdown thread. Patriots are in control.\n\nEradication (30-day furlough mark)\nTrut…',
#  "RT @100isNow: From national parks to marine animals, here's a look at some of the key impacts of the shutdown that relate to the environmen…",
#  'RT @PhillyD: Talking With Victims Of This Disastrous, Painful, &amp; Chaotic #GovernmentShutdown... https://t.co/gUwsQk7eBh',
#  'Will you join our community in supporting our neighbors and help supplement these gift boxes with any or all of the items below? #GovernmentShutdown https://t.co/SseTNwtQ3u',
#  'U.S. government shutdown: Websites insecure and inaccessible https://t.co/ZStTDNkXYT #ShutdownStories #GovernmentShutdown #USA #CyberSecurity',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @cspan: Who do you blame for the #GovernmentShutdown, now the longest in history?',
#  'RT @threadreaderapp: @dsm012 Hallo there is your unroll: Thread by @BLUEPRINT_Q: "1 - A short thread. Patriots are in control. Eradication…',
#  "An imperial #PresidentTrump cannot do a  #GovernmentShutdown over a policy dispute. Open the Government and we'll talk. https://t.co/BAqkWqG3gc",
#  'RT @BLUEPRINT_Q: 6 - Due to the #GovernmentShutdown (and "Reduction in Force" activation), Judicial courts must now coordinate independentl…',
#  "RT @shomaristone: NBC's @ShomariStone Reports: A mobile barber called The Shape Up King, offered free haircuts to furloughed government emp…",
#  'RT @nezetseguin: This is the least we can all do to keep bringing music to the people in this tough time #GovernmentShutdown @philorch @Met…',
#  "This is where I worship and if you are in need come to the place where we don't just talk the talk but we walk the walk. #cityofpraisefamilymisitries #COPFM #GovernmentShutdown #love #JESUS #CHRISTJESUS https://t.co/4QWuWg8Jfm",
#  'RT @BLUEPRINT_Q: 1 - A short #GovernmentShutdown thread. Patriots are in control.\n\nEradication (30-day furlough mark)\nTruth (DECLAS)\nJustic…',
#  "RT @robjh1: What in the devil is Fancy Nancy doing leaving DC when the gov't is shut down? How can she negotiate (not that she would do any…",
#  'RT @John_KissMyBot: 😂Bad News For Democrats \n\nLATINOS LIKE TRUMP EVEN MORE SINCE THE GOVERNMENT SHUTDOWN\n\n57% Of Registered Voters Say Woul…',
#  "@realDonaldTrump @WhiteHouse Just because there is a #GovernmentShutdown doesn't mean that there is a U.S. Congress Shutdown. Return every Member to their Chamber and hold live televised hearings on #BorderSecurity until compromised legislation is signed by @realDonaldTrump. #ShutdownPayforCongress",
#  'RT @AmericanLegion: (THREAD) Earlier this week, 41,000 members of the @uscoastguard woke up without paychecks in their bank accounts becaus…',
#  'To support the #IRS and not add to  their unpaid work, I will not be filing my taxes until the shutdown is resolved. \n#GovernmentShutdown',
#  'RT @aaas: The #GovernmentShutdown has reached Earth’s melting poles. IceBridge, a decadelong NASA campaign meant to secure a seamless recor…',
#  'RT @bmorebill: If you are suffering due to the current #GovernmentShutdown, FEEA has small grants available to furloughed/excepted feds ear…',
#  '#GovernmentShutdown #WallStunt\nA Small Alaska Town Reels as the Coast Guard Weathers On Without Pay https://t.co/tiTLdZRgIK',
#  'RT @In_loso_wetrust: Due to the government shutdown aye guy name “Joe the Handyman Johnson” 😂😂😂made it so workers can report back to work s…',
#  "RT @StormIsUponUs: That's $200,000,000 per work day in wages, and yet the traffic lights are still on, 911 still works, the stores are stil…",
#  'RT @APittsABC6: Arigna Irish Pub in North Providence is helping out during the #GovernmentShutdown. They’re serving up free pizzas and soft…',
#  'As @TSA suffers from #GovernmentShutdown, @Delta passenger smuggles gun aboard plane https://t.co/5JYPfrW3mD',
#  'RT @k8em0: Thank you @allanfriedman for organizing this #Shmoocon karaoke, and thank you so much to all who generously helped in raising ca…',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  "RT @shomaristone: NBC's @ShomariStone Reports: A mobile barber called The Shape Up King, offered free haircuts to furloughed government emp…",
#  'RT @John_KissMyBot: 😂Bad News For Democrats \n\nLATINOS LIKE TRUMP EVEN MORE SINCE THE GOVERNMENT SHUTDOWN\n\n57% Of Registered Voters Say Woul…',
#  'RT @EveryMindInc: This is an excellent list of available resources in our community for those impacted by the government shutdown.  Thanks…',
#  "RT @amjoyshow: .@DrJasonJohnson: Dems are just as dug in on this issue as Republicans. Pelosi's popularity has gone up since this happened.…",
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'Kristallnacht was murdering... #GovernmentShutdown is saving https://t.co/9CoTkJloCQ',
#  "#GovernmentShutdown Are postal employees being paid? They were courteous and pleasant to me today at 01830. I hope they weren't working without pay!",
#  'RT @BrettRSmith76: BEST. SHUTDOWN. EVER!!!\n#GovernmentShutdown #BingPow https://t.co/aWJljVnkwU',
#  'Just got a leaked transcript of Trump’s statement on the government shutdown at 3, that’ll show those democrats! 😅 @realDonaldTrump #GovernmentShutdown https://t.co/Ut37TQbZTi',
#  "RT @r3dgh0st: I'm still trying to run the numbers and figure out how Nancy Pelosi spends 1000 dollars a week on her booze bill.  Now we kno…",
#  'RT @CDNnow: Experts Continue To Debunk WaPo’s Claim About The Shutdown And Weather Forecasts https://t.co/h7xts7q8uY #governmentshutdown #m…',
#  '@nondualrandy Dude jealous that you have that much and hes working for free now #GovernmentShutdown',
#  "Als je je ineens bedenkt dat de gevolgen van die Amerikaanse #GovernmentShutdown toch niet zo heel ver weg zijn omdat je over een tijdje #ESTA's nodig hebt. https://t.co/rehRzFipFu",
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @John_KissMyBot: Gregg Gutfield Nails It\n\nNancy Pelosi Is Concerned About The Security At The ‘State Of The Union Address’\n\nBUT PELOSI I…',
#  "From national parks to marine animals, here's a look at some of the key impacts of the shutdown that relate to the environment.\n#100isNOW #GovernmentShutdown #EnvironmentalImpact #EnvironmentalJustice\nhttps://t.co/jXah4ZhdsY",
#  "Carrot looks like it's ready to start walking...maybe to the border......You know........the one with no wall.  😉 #strange #TrumpShutdown #GovernmentShutdown #BorderWall #Trending #carrot #OrangeManBad #overit #Veganuary2019 #FunniestTweets #laughing #GMO https://t.co/AybQNVs8vX",
#  'RT @AnosheKita: به راستي نانسی پلوسي ، چرا  در جریان تعطيلي دولت #GovernmentShutdown به طور ناگهانی تصمیم به بازدید از\n💥 بروکسل (HQ اتحادیه…',
#  'Pelosi Claims ‘Leak,’ White House Calls That a Flat-Out Lie https://t.co/RRrkIkjAOz via @LifeZette @micheleblood #MAGA #mapoli #Pelosi #Trump @foxnews #governmentshutdown #polizette @ingrahamangle @davidwebbshow',
#  'RT @5280Magazine: As we head into another week of the #governmentshutdown, don\'t forget to "Pack It Out" when venturing in the National Par…',
#  'RT @BLUEPRINT_Q: 6 - Due to the #GovernmentShutdown (and "Reduction in Force" activation), Judicial courts must now coordinate independentl…',
#  'RT @CHELLiEBXTCH: Please support my GoFundMe campaign: https://t.co/zV2ty5dhD6 @gofundme #GovernmentShutdown #Furlough #ShutdownStories #Go…',
#  '@Bryantasticc #GovernmentShutdown',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  "RT @amjoyshow: .@DrJasonJohnson: Dems are just as dug in on this issue as Republicans. Pelosi's popularity has gone up since this happened.…",
#  'RT @waywarddrift: Reducing our dependence on the economy is one of the most important things we can do in times like these\n#GovernmentShutd…',
#  'I feel like it’s time for Democrats to publicly offer $2.5 billion for the wall - or border security or whatever to demonstrate their commitment to the people and to not breaking our economy and let Trump save face.  This is getting dangerous.  #governmentshutdown @SpeakerPelosi',
#  'Hi Rudy! #BruceOhrTestimony #ObamaGate #FISABringsDownTheHouse #DeClassifyNow #FISA #DeClassFISA #MuellerReport #DOJ #Corrupt #DNC #HRC #BHO #Government #TransparencyNow #Public #GreatAwakening #GovernmentShutdown #WWG1WGA https://t.co/fADjmrNhM2',
#  'RT @10NewsMimi: Hyatt properties here in San Diego are coming together today outside of the USO building to offer free meals to San Diego A…',
#  'Something to remember as you travel through the #US amidst the #GovernmentShutdown https://t.co/pNcvbQcQV5',
#  'Hi Dan! #BruceOhrTestimony #ObamaGate #FISABringsDownTheHouse #DeClassifyNow #FISA #DeClassFISA #MuellerReport #DOJ #Corrupt #DNC #HRC #BHO #Government #TransparencyNow #Public #GreatAwakening #GovernmentShutdown #WWG1WGA https://t.co/XcL0R8iro7',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @chooselovetoday: Community #Poll RE-TWEET #TheTruthCommunity #GovernmentShutdown #BorderSecurity \n\nFLASH POLL:\n \nIn less than 6 hours,…',
#  'RT @5280Magazine: As we head into another week of the #governmentshutdown, don\'t forget to "Pack It Out" when venturing in the National Par…',
#  'Experts Continue To Debunk WaPo’s Claim About The Shutdown And Weather Forecasts https://t.co/h7xts7q8uY #governmentshutdown #mediabias https://t.co/dwT3oBG6lA',
#  'RT @StormIsUponUs: Remember the "Sanctions are coming" meme on the cabinet meeting table? Well, the #GovernmentShutdown effectively places…',
#  'RT @remember_the_1: #WhyWeMarch https://t.co/BXVCSxhuUR #MarchForLife #FridayFeeling #FridayMotivation #Friyay #FridayThoughts #FridayMorni…',
#  'The neighborhood also features #EbenezerBaptistChurch, the site of  Martin Luther King Jr’s baptism, his tenure as pastor, and his funeral. Special thanks to @Delta for opening this #nationalpark space during the #governmentshutdown! https://t.co/2UbZk6e5N9',
#  'RT @WokeChicksOnly: I knew that reality TV shows would be the downfall of good television programming...\n\nBut I never thought it would be t…',
#  '"What if Mexico\ndecided to build stairs\non their side of the wall?" is a friend\'s status today on FB.  \n #thewall #thestairs #Mexico #shutdown #GovernmentShutdown',
#  'RT @abc3340: JUST IN via @AP: @POTUS says he will make a "major announcement" on Saturday afternoon about the #GovernmentShutDown and #Bord…',
#  'RT @StormIsUponUs: #GovernmentShutdown is a multi-pronged work of genius. It exposes the Democrat agenda to swell voter rolls with illegals…',
#  'RT @FreedomWorks: Wanna get airport screeners paid during #GovernmentShutdown? \nPrivatize TSA! Private airline security already exists at 2…',
#  "RT @r3dgh0st: I'm still trying to run the numbers and figure out how Nancy Pelosi spends 1000 dollars a week on her booze bill.  Now we kno…",
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'Ahhh yes the old kidnapper strategy... ask for $5.7  billion in exchange for the safety of the children. Well played. #TrumpShutown #GovernmentShutdown #TrumpResign https://t.co/swiIdQGkjd',
#  "RT @shomaristone: NBC's @ShomariStone Reports: A mobile barber called The Shape Up King, offered free haircuts to furloughed government emp…",
#  '@realDonaldTrump @newtgingrich You haven’t accomplished shit! Maybe the ONLY THING YOU ACCOMPLISHED WAS SURPASSING THE #GovernmentShutdown RECORD! Congrats on screwing the American people. #maga',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @BLUEPRINT_Q: 1 - A short #GovernmentShutdown thread. Patriots are in control.\n\nEradication (30-day furlough mark)\nTruth (DECLAS)\nJustic…',
#  "RT @shomaristone: NBC's @ShomariStone Reports: A mobile barber called The Shape Up King, offered free haircuts to furloughed government emp…",
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'Trump to Make ‘Major Announcement’ on Border as Democrats Sweeten Offer   via @NYTimes #BorderWall #GovernmentShutdown  https://t.co/6fehmhhtCX',
#  'RT @aaas: The #GovernmentShutdown has reached Earth’s melting poles. IceBridge, a decadelong NASA campaign meant to secure a seamless recor…',
#  '"Trump to make announcement on border wall and government shutdown" https://t.co/4Kf6iWrpxR #Trump #wall #governmentshutdown',
#  "RT @amjoyshow: .@DrJasonJohnson: Dems are just as dug in on this issue as Republicans. Pelosi's popularity has gone up since this happened.…",
#  "RT @shomaristone: NBC's @ShomariStone Reports: A mobile barber called The Shape Up King, offered free haircuts to furloughed government emp…",
#  '#WhyWeMarch https://t.co/BXVCSxhuUR #MarchForLife #FridayFeeling #FridayMotivation #Friyay #FridayThoughts #FridayMorning #God #NationalTriviaDay #Jesus #FridayReads #coffee #meditation #WomansMarch2019 #AOC #GovernmentShutdown #NYC #love #Seattle #MarchForLife2019 #WomansWave https://t.co/GMbjLtcRki',
#  'RT @BLUEPRINT_Q: 6 - Due to the #GovernmentShutdown (and "Reduction in Force" activation), Judicial courts must now coordinate independentl…',
#  '#GovernmentShutdown #GovernmentShutdownstorie#philly https://t.co/IxvxnUgO81',
#  'This #GovernmentShutdown is making me feel trapped in my house. Also leaving me with no motivation to leave.',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @StormIsUponUs: #GovernmentShutdown is a multi-pronged work of genius. It exposes the Democrat agenda to swell voter rolls with illegals…',
#  'RT @bluewavegal: We’ve made four trips to the airport this week. People are so generous and want to take care of the federal employees who…',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @karen_erotoo1: @SpeakerPelosi @SenSchumer have you read Art. IV, Sec. 4 of the #\nConstitution? Here it is. 👇👇  READ IT!\n#buildthewall #…',
#  '#GovernmentShutdown day 29! #DonaldTrump plans to offer TEMPORARY protection #DACA #dreamers etc if he can get his stupid #racist #BorderWall . The protection is TEMPORARY but the border wall is forever ! How the hell is this a deal?',
#  'Members of the @USCG are usually the ones helping others. Today the community came out to help them. 150 families - affected by the #GovernmentShutdown - served fresh food, nonperishables &amp; pet food from @MarinHumane #ShutdownStories #FoodForAll https://t.co/Wn41PbL5aJ',
#  'RT @mcspocky: @DeplorableTrump @mightyheidip Who do you blame most for the #GovernmentShutdown, now the longest in history?',
#  '@CVGairport I’m traveling out of CVG Monday. Is there a food bank or mechanism whereby I can support our hard-working #TSA agents? #GovernmentShutdown',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @nbcwashington: Have any #GovernmentShutdown discounts to add to the list? Email tips@nbcwashington.com or tweet us! https://t.co/MdlLpM…',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @a_hammerschlag: A delicate ecosystem exists between Boquillas, Mexico and Big Bend National Park. With the closure of the border crossi…',
#  '@amyklobuchar Maybe you should fund the Wall first and then we’ll negotiate. I remember how the #democrats lied to Reagan.  Never Again will I trust. #democrat! #GovernmentShutdown #BuildTheWall #CNN #MSNBC',
#  'Another reason why the #GovernmentShutdown needs to end. #governmentemployees are being affected by #healthcare costs https://t.co/5MfM9VJEm1 #ShutdownStories #GovernmentShutdownstories',
#  'RT @StormIsUponUs: Nancy, why during the #GovernmentShutdown did you suddenly decide to visit: \n💥 Brussels (EU HQ)\n💥 Egypt (Muslim Brotherh…',
#  'With the #GovernmentShutdown the #waste problem in #NationalParks is even more apparent. Lots to do to reduce waste in our parks. https://t.co/8DmBQ4MOod @leavenotrace @adanovitch @NatlParkService #zerowaste',
#  'RT @AshLopezRadio: The things that stuck with me from my conversation with Drapela are the kinds of big and small sacrifices he and his fam…',
#  'RT @BLUEPRINT_Q: 1 - A short #GovernmentShutdown thread. Patriots are in control.\n\nEradication (30-day furlough mark)\nTruth (DECLAS)\nJustic…',
#  'RT @NYDailyNews: Are you a furloughed federal worker?\n\nWhile it doesn’t make up for being deprived of a paycheck, you may be able to take a…',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @GinaMarie497: An anonymous senior official in Trump administration writes an interesting op-ed....\n#Shutdown\n#GovernmentShutdown\n\nhttps…',
#  'RT @John_KissMyBot: Mad Maxine Waters Wants Billions To End Homelessness BUT No Funding For A Wall\n\nOne Problem Mad Max, If Illegals Keep C…',
#  'RT @RodBurlingame: #BuildTheWall \n#governmentshutdown https://t.co/rpjHO2xaSz',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  "RT @r3dgh0st: I'm still trying to run the numbers and figure out how Nancy Pelosi spends 1000 dollars a week on her booze bill.  Now we kno…",
#  '@realDonaldTrump expected to make new deal to Democrats to end the government shutdown https://t.co/NMiSLevkOH #GovernmentShutdown https://t.co/kHJFPME5iV',
#  'RT @karen_erotoo1: @SpeakerPelosi @SenSchumer have you read Art. IV, Sec. 4 of the #\nConstitution? Here it is. 👇👇  READ IT!\n#buildthewall #…',
#  "RT @Art4JusticeFund: With the #governmentshutdown, over 4000 people that the #FirstStepAct could've released from federal prison are stuck.…",
#  "We Work for the Federal Government and It's Time to Strike https://t.co/cMASVlBabj #governmentshutdown #strikes #unions https://t.co/U4IjlKBYtO",
#  'Trump Wrong About Wall Effect in El Paso - https://t.co/QpYHRcLGnA https://t.co/SBoNIHOVUw\n\n#elchuco #elpaso #governmentshutdown',
#  "RT @proxcee: That's probably gonna get annoying after awhile..\n\n#BuildTheWall\n#GovernmentShutdown\n\nhttps://t.co/GRV9lX2cBY",
#  'RT @waywarddrift: Reducing our dependence on the economy is one of the most important things we can do in times like these\n#GovernmentShutd…',
#  '#Brexit #GovernmentShutdown #thewall #xenophobia #hatred https://t.co/s3fqtf3lok',
#  'What she said Ana how she said it. #real #GovernmentShutdown https://t.co/bLriph017G',
#  'As we head into another week of the #governmentshutdown, don\'t forget to "Pack It Out" when venturing in the National Parks or on federal land.  #packitout #leavenotrace https://t.co/VKoikffTex',
#  "RT @Periapt: @realDonaldTrump If the #GovernmentShutdown were a movie, wouldn't @POTUS @realDonaldTrump be the kidnapper , the blackmailer,…",
#  'RT @aaas: The #GovernmentShutdown has reached Earth’s melting poles. IceBridge, a decadelong NASA campaign meant to secure a seamless recor…',
#  "RT @StormIsUponUs: That's $200,000,000 per work day in wages, and yet the traffic lights are still on, 911 still works, the stores are stil…",
#  "@realDonaldTrump If the #GovernmentShutdown were a movie, wouldn't @POTUS @realDonaldTrump be the kidnapper , the blackmailer, or the terrorist?\n\n#BuildTheWall\n#EndTheShutdown\n#OpenTheGovernment",
#  'The latest Die Spacefuture Zeitung! https://t.co/JuZzyV8lp7 Thanks to @StuartMcclung @NASAWatch #shutdown #governmentshutdown',
#  'Government shutdown day 29!\n\nSo this is what YOUR president (@realDonaldTrump ) tweeted yesterday. Unless you are saying the shutdown is over the "major announcement" is going to be "major crap" to me. \n\n#CoachChaun \n#governmentshutdown\n#TrumpShutdown https://t.co/pEilUaQqaJ',
#  'RT @WomenforTrump: Up next on @cnn, @FWhitfield is having on a single mom who is not working during the #GovernmentShutdown. Why doesn’t sh…',
#  "@realDonaldTrump @newtgingrich If the #GovernmentShutdown were a movie, wouldn't @POTUS @realDonaldTrump be the kidnapper , the blackmailer, or the terrorist?\n\n#BuildTheWall\n#EndTheShutdown\n#OpenTheGovernment",
#  'RT @kathyluwho: In #KC courts, which sees immigration cases from #Missouri and #Kansas, 557 appearances were canceled in first 3 weeks of #…',
#  'Arigna Irish Pub in North Providence is helping out during the #GovernmentShutdown. They’re serving up free pizzas and soft drinks from 2-4pm today for federal workers! They say if the shutdown continues they will likely do this again @ABC6 https://t.co/3LgVBAWTZy',
#  "@realDonaldTrump If the #GovernmentShutdown were a movie, wouldn't @POTUS @realDonaldTrump be the kidnapper , the blackmailer, or the terrorist?\n\n#BuildTheWall\n#EndTheShutdown\n#OpenTheGovernment",
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  '#SendABrick not the brightest idea. How about a new hashtag...\n#SendATurd to #DonaldTrump &amp; #MitchMcConnell until this ridiculous #GovernmentShutdown is ended. https://t.co/eGrPwhZ1Xz',
#  'RT @John_KissMyBot: 😂Bad News For Democrats \n\nLATINOS LIKE TRUMP EVEN MORE SINCE THE GOVERNMENT SHUTDOWN\n\n57% Of Registered Voters Say Woul…',
#  "@realDonaldTrump If the #GovernmentShutdown were a movie, wouldn't @POTUS @realDonaldTrump be the kidnapper , the blackmailer, or the terrorist?\n\n#BuildTheWall\n#EndTheShutdown\n#OpenTheGovernment",
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  "RT @shomaristone: NBC's @ShomariStone Reports: A mobile barber called The Shape Up King, offered free haircuts to furloughed government emp…",
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  "@realDonaldTrump If the #GovernmentShutdown were a movie, wouldn't @POTUS @realDonaldTrump be the kidnapper , the blackmailer, or the terrorist?\n\n#BuildTheWall\n#EndTheShutdown\n#OpenTheGovernment",
#  'RT @COSProject: If this isn’t the truth we don’t know what is.😂 #GovernmentShutdown https://t.co/9j5HtVuYj8',
#  'Decentralization Is the Solution to the Government Shutdown\nhttps://t.co/y1cGQ7MbwG\n#decentralization #GovernmentShutdown',
#  'RT @COSProject: If this isn’t the truth we don’t know what is.😂 #GovernmentShutdown https://t.co/9j5HtVuYj8',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'Your friendly reminder that the "mantle" for the #GovernmentShutdown rests entirely on Donald Trump. Don\'t fall for any phony compromise, @SenateDems, @HouseDemocrats, @chuckschumer, @SpeakerPelosi.\n#NoWallEver',
#  "RT @r3dgh0st: I'm still trying to run the numbers and figure out how Nancy Pelosi spends 1000 dollars a week on her booze bill.  Now we kno…",
#  'I was under the impression that maybe the @USPS was not operating as usual because of the government shutdown...the tracking data has been horrible. Saying not delivered, but actually delivered and vice versa. But nope, still running as usual :) #GovernmentShutdown',
#  'Some of the 380,000 furloughed or unpaid federal workers are signing up with @Uber, @Fiverr, @Airbnb or @TaskRabbit as second jobs, according to @packaged_facts\n\n#mrx #economy #GovernmentShutdown #Shutdown #SideJobs #SideGigs #money #FederalWorkers\n\nhttps://t.co/HTmBHz2wzi',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @TSWHITLOW: As Shutdown Continues, @CityofBostonCU Extends Furlough Loan Assistance to federal workers, who meet their membership criter…',
#  "If the #GovernmentShutdown were a movie, wouldn't @POTUS @realDonaldTrump be the kidnapper , the blackmailer, or the terrorist?\n\n#BuildTheWall\n#EndTheShutdown\n#OpenTheGovernment",
#  'RT @AmericanLegion: (THREAD) Earlier this week, 41,000 members of the @uscoastguard woke up without paychecks in their bank accounts becaus…',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'RT @AmericanLegion: (THREAD) Earlier this week, 41,000 members of the @uscoastguard woke up without paychecks in their bank accounts becaus…',
#  'RT @jojoh888: .@SpeakerPelosi defended MS-13 gang members\n@SenSchumer supports open borders\n@ananavarro filed her nails on t.v.\n@TheDemocra…',
#  'RT @John_KissMyBot: 😂Bad News For Democrats \n\nLATINOS LIKE TRUMP EVEN MORE SINCE THE GOVERNMENT SHUTDOWN\n\n57% Of Registered Voters Say Woul…',
#  'RT @H_Combs: The Trump admin is rushing forward during the government shutdown with plans to open the Arctic Refuge to oil drilling. Take a…',
#  'RT @nezetseguin: This is the least we can all do to keep bringing music to the people in this tough time #GovernmentShutdown @philorch @Met…',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  '@JohnStossel @realDonaldTrump @SpeakerPelosi @SenSchumer Air Traffic Control IS essential as is the Coast Guard.  Both should be funded and paid.  Aren’t private TSA, government contracts?  Therefore their contractors aren’t getting paid.  A few holes in your story.  But yes to much of it. #GovernmentShutdown',
#  "RT @shomaristone: NBC's @ShomariStone Reports: A mobile barber called The Shape Up King, offered free haircuts to furloughed government emp…",
#  'The #GovernmentShutdown is about power at the end of the day🤦🏽\u200d♀️',
#  'RT @gbroh10: Stand Your Ground #POTUS #GovernmentShutdown! \n\nThey are trying to disarm #Americans for a takeover of our country. \n\n#2ADefen…',
#  'Well #2019 off to one hell of a start #GovernmentShutdown #Maga 😂🤦🏾\u200d♂️🔥🤣 https://t.co/1s7sbdeLGX',
#  "RT @r3dgh0st: I'm still trying to run the numbers and figure out how Nancy Pelosi spends 1000 dollars a week on her booze bill.  Now we kno…",
#  'RT @threadreaderapp: @dsm012 Hallo there is your unroll: Thread by @BLUEPRINT_Q: "1 - A short thread. Patriots are in control. Eradication…',
#  "I'm raising money for Govt Shutdown Help for the Bristol Family. Click to Donate:  https://t.co/2fQlgLQoWO via @gofundme #governmentshutdown #shutdown #trumpshutdown #furloughed workers",
#  '"I demand that we bring in every third world refugee and illegal alien, and put them in areas I don\'t live in."\n                                   -Lib\n#EndBorderCrisis #GovernmentShutdown\n#caravan\n#immigration',
#  'RT @StormIsUponUs: Nancy, why during the #GovernmentShutdown did you suddenly decide to visit: \n💥 Brussels (EU HQ)\n💥 Egypt (Muslim Brotherh…',
#  "RT @shomaristone: NBC's @ShomariStone Reports: A mobile barber called The Shape Up King, offered free haircuts to furloughed government emp…",
#  "I'm for any good faith olive branch that will drop the curtain on an elephant in the room #GovernmentShutdown and get the money presses running again.\n\nIf Trump wants to be the one to shepherd neutrality, great.\n\nWe'll take him under advisement at 3 p.m.\n\n-BB",
#  "Not funny. No groceries, no insurance so I can't update my tags, Can't provide for my family, still have to buy gas so I can provide #InvoluntaryServitude #GovernmentShutdown",
#  '@realDonaldTrump @newtgingrich What have you done? Tanked the stock market &amp; economy, started unnecessary trade wars, sought to withdraw from NATO, met 5 times with your #MasterPutin withdrew from Syria, and #GovernmentShutdown over an idiotic wall you promised Mexico would pay for? #RussianAsset',
#  "I'm still trying to run the numbers and figure out how Nancy Pelosi spends 1000 dollars a week on her booze bill.  Now we know why she said a 2000 dollar tax cut was just crumbs. #GovernmentShutdown #NancyGotGrounded",
#  'RT @RPCoalition: .@RevJJackson &amp; @RPCoalition are giving away two $25 @Food4Less gift cards to 150 federal workers during the #governmentsh…',
#  '@realDonaldTrump let’s get the deal done✅ time to build the wall #Trump #BuzzFeedNews #BuildTheDamnWall #MAGA #GovernmentShutdown #SchumerPelosiShutdown https://t.co/UmaYpvi1zI',
#  'If you or someone you know has been affected by the #GovernmentShutdown and would be open to be interviewed for a story, please reach out via DM or editor@dailyegyptian.com. #SIUC #Carbondale #Illinois',
#  "RT @jojoh888: I'm betting you that Chuck Schumer doesn't want you to retweet this, it would be a shame if it went viral. 🤔 Democrats only o…",
#  'RT @aaas: The #GovernmentShutdown has reached Earth’s melting poles. IceBridge, a decadelong NASA campaign meant to secure a seamless recor…',
#  'RT @AskPreciousCat: FULL VIDEO precious kitteh talks #GovernmentShutdown cat style https://t.co/UHINUVZSou',
#  '@ADAPTmikey @GOP @realDonaldTrump #IfTwitterTweetedBack #snowpocalypse #GovernmentShutdown https://t.co/touDJ2EvUL',
#  'RT @Kris_Sacrebleu: Trump to make new offer to Democrats as government shutdown drags on - The Washington Post\n\nHe’ll offer “temporary” pro…',
#  'RT @NatalieABrand: "A senior administration official told @MajorCBS that President Trump will present what the White House believes could b…',
#  "RT @kylegriffin1: As the shutdown hits four weeks, remember what Trump said on Dec. 11.\n\nTrump: If we don't get what we want ... I will shu…",
#  'Today Trump said that he\'ll make a major announcement📣\nI guess he will tell that the dreaded doomsday clock is slow and he will stay at home next week to fix it😬\nAlso he will say that he needs money for his Wall urgently cause "shutdown" will Make Americans Go Away to Mexico😎',
#  "@IngrahamAngle @ElizBelill @realDonaldTrump Agreed. If it will end this shutdown, I'm all for it.",
#  'RT @AmoneyResists: Shep Smith: Trump owns the shutdown.\nChris Wallace: Well, it takes two to tango.\nShep Smith: There’s no tango here. He s…',
#  'RT @theCorey: The politicization of our national security by Democrats must come to an end.\n\nThe reason why we have gone through this gover…',
#  "RT @kylegriffin1: As the shutdown hits four weeks, remember what Trump said on Dec. 11.\n\nTrump: If we don't get what we want ... I will shu…",
#  'RT @DanRather: There is a push by some to say that "both sides" are to blame for the shutdown. I would agree. Both sides of Pennsylvania Av…',
#  'RT @GovofCO: I have authorized an emergency rule that makes all unpaid federal workers eligible for unemployment benefits, whether they are…',
#  "RT @kylegriffin1: As the shutdown hits four weeks, remember what Trump said on Dec. 11.\n\nTrump: If we don't get what we want ... I will shu…",
#  "RT @billmaher: This shutdown is not about the wall. It's about the wallet. And it's more proof that the great American middle class is disa…",
#  'RT @politvidchannel: BREAKING: PayPal Said it is committing to fund $25 million of interest-free cash advances to Help unpaid federal worke…',
#  'RT @Brasilmagic: Romney backs Trump in shutdown showdown, questions Pelosi \n\nRemember who Mitt really is. https://t.co/k66HXkbImv',
#  'RT @aletweetsnews: #WomensMarch2019 singing a shutdown-themed take on “ain’t gonna let nobody turn me around” on their way by the Trump Hot…',
#  'RT @nowthisnews: Cardi B went off on Trump and the government shutdown — and it 👏 was 👏 beautiful https://t.co/ycrjbDtdo8',
#  'RT @WMM_podcast: Bush delivers pizza to Secret Service detail, calls for end to shutdown #WordsMatter https://t.co/zS6kmHatiJ',
#  "RT @nowthisnews: 'My children come home from school hungry, they open the refrigerator, and there isn't anything.' — This is what Trump's s…",
#  'RT @seanhannity: **WHITE HOUSE: “Under no circumstances during a government shutdown will any government owned, rented, leased, or chartere…',
#  "RT @kylegriffin1: As the shutdown hits four weeks, remember what Trump said on Dec. 11.\n\nTrump: If we don't get what we want ... I will shu…",
#  '@DaveMar16751315 @realDonaldTrump What ! He contributed to their deaths by saying we had beat ISIS and he was pulling our troops . He owns it just like the shutdown that’s holding our federal employees from getting paid.',
#  'RT @nowthisnews: Cardi B went off on Trump and the government shutdown — and it 👏 was 👏 beautiful https://t.co/ycrjbDtdo8',
#  'RT @dbongino: Latino Job Approval of Trump SURGES in Midst of Govt Shutdown Over Border Wall Funding https://t.co/HAqstQDGw5',
#  "RT @CBSNews: Government shutdown puts Colorado's forests at greater risk for wildfires https://t.co/wcxhl9r8UF https://t.co/CBKKG47BiI",
#  'RT @MadelyneRants: 💙All over Twitter I see stories of amazing people pitching in to take care of federal workers and their families during…',
#  'RT @chrislhayes: One reason we call the shutdown the “Trump shutdown” on my show is that Trump said on camera that it was his shutdown and…',
#  'RT @politvidchannel: Shep Smith Called out Chris Wallace for blaming “both sides” for the shutdown. \n\nChris Wallace: “I mean it takes two t…',
#  'RT @AndrewPollackFL: Finally a Senator that works for the people!\nSenator @ScottforFlorida is trying to pass a bill to stop Congress from g…',
#  'RT @activist360: According to HUD, the Trump shutdown is causing senior citizens, low income families, and people w/disabilities to tap int…',
#  'RT @AmoneyResists: Shep Smith: Trump owns the shutdown.\nChris Wallace: Well, it takes two to tango.\nShep Smith: There’s no tango here. He s…',
#  'RT @dbongino: Latino Job Approval of Trump SURGES in Midst of Govt Shutdown Over Border Wall Funding https://t.co/HAqstQDGw5',
#  'RT @elwasson: House Democratic aide rejects Trump offer  saying it is not permanent solution for Dreamers and still contains wasteful wall…',
#  'A Small Alaska Town Reels as the Coast Guard Weathers On Without Pay #govermentshutdown https://t.co/TEyIpNLExy',
#  'RT @shannonrwatts: Newt Gingrich also lost his job after badly handling a government shutdown, so.... https://t.co/xkG2uNg6p3',
#  "@EdKrassen @krassenstein @realDonaldTrump This is why Dems are being blamed for the shutdown in places that matter like Ohio.... California and New York ain't gonna win you the big prize alone..... seriously you guys it's time to compromise for real...You getting all you want and the other side getting nothing don't work",
#  'RT @seanhannity: **WHITE HOUSE: “Under no circumstances during a government shutdown will any government owned, rented, leased, or chartere…',
#  'RT @kylegriffin1: Cardi B has some NSFW thoughts on Trump and the government shutdown. https://t.co/hGOA4jBIHi https://t.co/1vaMdRLo8m',
#  'RT @mkraju: Not much support among Dems for this Trump plan on two fronts: they want permanent protections for DACA recipients, not just te…',
#  "RT @krassenstein: - Trump approval polls way down\n\n- Fox News' Shep Smith attacking Trump on Shutdown\n\nConservative columnist George Will a…",
#  'RT @Jali_Cat: All @TheDemocrats NEED TO BE PURGED OUT OF OUR GOVERNMENT‼️‼️‼️‼️\n\nSomeone tell @RepAdamSchiff when there is a GOVERNMENT SHU…',
#  "@realDonaldTrump Thanks for the warning.  I'll switch to Netflix.  Unless you're giving up on making Americans pay for a wall AND ending the shutdown, I don't wanna listen to your LIES https://t.co/5IM31USu4N",
#  'RT @TheEllenShow: The government shutdown left these sisters in a tough spot, so our friends at Cheerios helped me purchase the most expens…',
#  '@RepSusieLee @SpeakerPelosi @senatemajldr Mitch McConnell is as responsible for this Shutdown as Trump is, because Mitch could end it in a second, but he refuses to do so.\n#EvilMitchMcConnell\n#EvilTrump\n#TrumpShutdown',
#  'George W. Bush Calls to Reopen Government, Delivers Pizzas to Unpaid Secret Service Agents https://t.co/Ih7L4m3vqZ https://t.co/HvUcbnkbeE',
#  "RT @billmaher: This shutdown is not about the wall. It's about the wallet. And it's more proof that the great American middle class is disa…",
#  'RT @chefjoseandres: Important News! #ChefsForFeds is expanding across the nation 🇺🇸 to serve those impacted by the shutdown. Join us and to…',
#  'RT @SaysHummingbird: This is simply cruel and goes against the constitution!\n\nTrump administration bans TSA officials from talking about pr…',
#  'RT @DanaPerino: Dems are going to have to come to the table with a counter - or the shutdown blame shifts to them after this afternoon http…',
#  "RT @theTrumpSpring: Yes.. continue the shutdown until the obstructionists can be removed. James O'Keefe exposed a number of them, and there…",
#  'Trump Pesta Hamburger, Bush Sumbangkan Pizza untuk Pegawai Terimbas Shutdown #Shutdown https://t.co/04u5PrIenT',
#  'RT @SaraCarterDC: I’d like to hear your thoughts on what @realDonaldTrump may say tomorrow? Also, how do you feel about the standoff and go…',
#  'RT @HeshimuK: @NatalieABrand @cadalakjack @MajorCBS #shutdownstories....he needs to end the shutdown in his mind now because no one is blai…',
#  'RT @TheGoodGodAbove: Hey dipshits @realDonaldTrump and @senatemajldr,\n\nWhat’s it gonna take to end the shutdown?\n\nA plane crashing? ✈️ 💥\n\nW…',
#  '"The ongoing government shutdown is impacting local federal workers who are not receiving paychecks." Catholic Charities can help. https://t.co/D0b2RsERpZ https://t.co/c68hSya3Ho',
#  "Marist Poll: Trump's Support Among Hispanics Jumps 19 Points Amid Shutdown | https://t.co/wWtMpvlDLm https://t.co/Eb4AP14t3S via @Newsmax",
#  'RT @charliekirk11: Government employees not receiving a paycheck during the shutdown will get back pay\n\nAmerican families who lost their lo…',
#  'RT @IlhanMN: Sign on: Tell @senatemajldr McConnell and @realDonaldTrump to end the shutdown: https://t.co/XzLnDDraJ3\n\n#WheresMitch https://…',
#  'RT @lori_everly: Pelosi doesn’t give a crap about those in the shutdown.  She proves it taking 7 members and 80 of their family members on…',
#  'UPDATE: Trump expected to make new shutdown offer to Democrats https://t.co/fX90wJcZVp',
#  'RT @chrislhayes: One reason we call the shutdown the “Trump shutdown” on my show is that Trump said on camera that it was his shutdown and…',
#  "Trump accuses Pelosi of being 'controlled by the radical left,' hours before White House statement on shutdown\n\nhttps://t.co/giKQ0aBT2U",
#  "RT @kylegriffin1: As the shutdown hits four weeks, remember what Trump said on Dec. 11.\n\nTrump: If we don't get what we want ... I will shu…",
#  'RT @mkraju: Not much support among Dems for this Trump plan on two fronts: they want permanent protections for DACA recipients, not just te…',
#  'RT @DonaldJTrumpJr: Hey @Amy_Siskind why did you delete your tweet comparing the government shutdown to Kristallnacht? Asking for a few mil…',
#  "RT @atweetingtwit: hi friends, just in case you didn't know: the government shutdown means food stamps are basically going away in February…",
#  "RT @nowthisnews: 'My children come home from school hungry, they open the refrigerator, and there isn't anything.' — This is what Trump's s…",
#  '"Temporary"? No deal.  https://t.co/9RLN47JNBL',
#  'RT @SpryGuy: Wrong. Exactly one man can end the shutdown: Mitch McConnell. He has a bill that would end it sitting on his desk, already pas…',
#  'RT @GregRubini: 8. why Pelosi wanted to fly away at all costs?\n\nwhy Pelosi wanted to fly away with Adam Schiff, plus other 6 Dem  congressm…',
#  "RT @nowthisnews: 'My children come home from school hungry, they open the refrigerator, and there isn't anything.' — This is what Trump's s…",
#  'President Trump expected to announce offer to end shutdown in Saturday speech https://t.co/C4ELTlF3DC',
#  'RT @DonaldJTrumpJr: Hey @Amy_Siskind why did you delete your tweet comparing the government shutdown to Kristallnacht? Asking for a few mil…',
#  'RT @realDonaldTrump: I will be making a major announcement concerning the Humanitarian Crisis on our Southern Border, and the Shutdown, tom…',
#  "RT @kylegriffin1: As the shutdown hits four weeks, remember what Trump said on Dec. 11.\n\nTrump: If we don't get what we want ... I will shu…",
#  "RT @Gugustt: #Tchad\n\n#Maalla_Gatétou \n#ShutDown\n#SocialNetworks\n#Africtivistes @AFRICTIVISTES\nPour une liberté d'accès à #Internet au Tchad…",
#  'RT @chefjoseandres: Important News! #ChefsForFeds is expanding across the nation 🇺🇸 to serve those impacted by the shutdown. Join us and to…',
#  'RT @TheGoodGodAbove: Hey dipshits @realDonaldTrump and @senatemajldr,\n\nWhat’s it gonna take to end the shutdown?\n\nA plane crashing? ✈️ 💥\n\nW…',
#  'Stage 2 shutdown due at 1928 UTC, but coverage has gone secret for this @NatReconOfc payload launch',
#  'RT @DanRather: There is a push by some to say that "both sides" are to blame for the shutdown. I would agree. Both sides of Pennsylvania Av…',
# ...
#  'RT @realDonaldTrump: Mexico is doing NOTHING to stop the Caravan which is now fully formed and heading to the United States. We stopped the…',
#  'RT @DemWrite: A GOP Congressman from Texas is calling the “crisis” at the border a “myth”, and Trump’s wall “ancient”.\nhttps://t.co/WiMq762…',
#  '@EdKrassen @krassenstein @realDonaldTrump What do u have against Americans Mr. Ed? Build the wall!',
#  'RT @vaultedthewall: I got complimented on my @eos_10 logo on the recommend a podcast wall 😢❤ thank you random stranger https://t.co/KuQtSZu…',
#  '@realDonaldTrump A wall will take 15-20 years to build. You don’t tell your ignorant base that though. Why not, donny? It doesn’t fit your “The Mexicans are coming “ dog whistle. We need security NOW. The best way is with technology NOW. And guards NOW. Not a wall in 15 years. #TrumpLies',
#  'RT @GOPChairwoman: “Everything we’re asking for – whether it’s the wall or barrier, whether it’s the technology, whether it’s the drug-dete…',
#  'RT @FiveRights: Simplest issue ever.\nIf you care abt Americans, you want the wall.\nIf you care abt something else more, like importing Dem…',
#  'RT @PeteHegseth: As the Wall debate continues...need to look at the connection between open borders, the 2020 census &amp; redistricting. Illeg…',
#  'RT @pattonoswalt: This is the Vietnam vet the kids from @CovCathColonels were mocking. Chanting “BUILD THAT WALL” to a Native American. Thi…',
#  'RT @TylerDinucci: The image of white teens in “Make America Great Again” hats screaming “build the wall!” at a Native American Vietnam vete…',
#  "Mirror mirror on the wall can you teach me to love myself beyond the vanity teach me to place no one above myself we can't keep meeting like this I won't keep meeting like this I'm begging you mirror mirror on the wall",
#  'RT @RealOmarNavarro: Declaring an Emergency to Build a Border Wall a great way to get the job done. Let’s build that wall. The true art of…',
#  "RT @george_capen: Trump is about to propose a new deal to get wall funding. The problem is: THAT'S NOT HIS JOB! It's the Congress' job to h…",
#  'RT @pattonoswalt: This is the Vietnam vet the kids from @CovCathColonels were mocking. Chanting “BUILD THAT WALL” to a Native American. Thi…',
#  'RT @SarahPalinUSA: Report: Drug Smugglers Brought 700LBS Of Cocaine Across The Border In Area Without Wall https://t.co/Gh1NoJHJdT',
#  "RT @PatriotRocker69: Nancy Pelosi's Previous Taxpayer Funded Trips Were Pretty Fancy\n\nApparently hypocrite @SpeakerPelosi lives it up prett…",
#  'RT @worldly401: @StormIsUponUs the Border Patrol station at Sandy Dunes, Az reports that work on the Wall has come to a standstill:  every…',
#  'If he is given the wall all US lose!  No wall - waste of money! No listening to lying Donald @SenateDems @HouseDemocrats @HouseGOP @SenateGOP #NoWall #EndTrumpShutdown https://t.co/XBKQqHGNqN',
#  'RT @RonaldKlain: Wait:  Trump wants to trade a PERMANENT wall for THREE YEARS of protection for Dreamers (the Bridge Act), with no protecti…',
#  'RT @AndyKroll: NEW: Rep. Will Hurd — a ***Texas Republican*** — tells @RollingStone that @realDonaldTrump\'s border crisis is a "myth."\n\nHur…',
#  "RT @pacelattin: Trump says San Antonio is an example of a city where a border wall has worked. \n\nSan Antonio isn't on the border.  Nor has…",
#  'RT @realDonaldTrump: Mexico is doing NOTHING to stop the Caravan which is now fully formed and heading to the United States. We stopped the…',
#  "@axios Take it. Trump will be gone before a $billion of the money can be spent on that damned wall.  And what does get built will be a lasting monument to Trump's Folly covered with graffiti.",
#  '@bjclarke6 @CNN I don\'t think I\'ve ever been in any bathroom that didn\'t have graffiti on the wall of the stall.  A lot of "f honkeys" and "Kill crackers" type of stuff, never whined to my boss and tried to destroy the company I work for because I worked with racist black guys.',
#  'RT @cmclymer: Trump is expected to offer a three-year extension for DACA recipients in exchange for the $5.7 billion for the border wall.…',
#  "@realDonaldTrump Thanks for the warning.  I'll switch to Netflix.  Unless you're giving up on making Americans pay for a wall AND ending the shutdown, I don't wanna listen to your LIES https://t.co/5IM31USu4N",
#  "RT @billmaher: This shutdown is not about the wall. It's about the wallet. And it's more proof that the great American middle class is disa…",
#  'RT @Jilly379: @mkraju Why aren’t you saying the wall was supposed to be paid for by Mexico!?!',
#  'Yeah if I were Democrats I would accept Border Wall for the DREAM Act after the Government was opened and or I would accept Border Wall for DREAM Act plus HR1 with opening the Government. https://t.co/UKUcC0i1mD',
#  'Trump , the malignant genius,most likely will give his # SOTU speech today disguising it as my wall speech. https://t.co/MSvIkQMO21',
#  'RT @pattonoswalt: This is the Vietnam vet the kids from @CovCathColonels were mocking. Chanting “BUILD THAT WALL” to a Native American. Thi…',
#  'RT @AngrierWHStaff: I’m conflicted about this upcoming POTUS announcement. \n\nEven if the Dems agree to give 5.7B for the wall in exchange f…',
#  'RT @RealOmarNavarro: Declaring an Emergency to Build a Border Wall a great way to get the job done. Let’s build that wall. The true art of…',
#  'RT @SarahPalinUSA: Report: Drug Smugglers Brought 700LBS Of Cocaine Across The Border In Area Without Wall https://t.co/Gh1NoJHJdT',
#  'Build the wall! https://t.co/QmwB9Tgp1s',
#  'RT @SarahPalinUSA: Report: Drug Smugglers Brought 700LBS Of Cocaine Across The Border In Area Without Wall https://t.co/Gh1NoJHJdT',
#  "RT @ScottPresler: President Trump could offer the democrats everything they want &amp; Pelosi still wouldn't give Trump $ for the wall. \n\nWith…",
#  'Fund the wall dopey https://t.co/RBQ17mAcGd',
#  'RT @SarahPalinUSA: Report: Drug Smugglers Brought 700LBS Of Cocaine Across The Border In Area Without Wall https://t.co/Gh1NoJHJdT',
#  'RT @burgessev: House Dem aide on Trump plan: “This cannot pass the House or Senate.\n\nThe President must agree to re-open government and joi…',
#  "@steelserpent @cindyyy777 @Barbann76 @4originalintent @SmokiestLemming I have. 59% don't think a wall from sea to shining sea is necessary to protect the border. That is in part why there's now a strong Democratic majority in the House. Dems offered $1.6 B for wall in Nov &amp; Trump turned it down. They have no incentive to give even that now.",
#  "RT @ScottPresler: President Trump could offer the democrats everything they want &amp; Pelosi still wouldn't give Trump $ for the wall. \n\nWith…",
#  "RT @ArsenalReport: Take it easy on booing Marcos Alonso guys, it's not like he got behind the wheel of a car over the drink drive limit and…",
#  'RT @funder: BREAKING: Trump plans to propose extending DACA &amp; TPS status for a limited time this afternoon in exchange for wall funding &amp; r…',
#  'RT @realDonaldTrump: Mexico is doing NOTHING to stop the Caravan which is now fully formed and heading to the United States. We stopped the…',
#  'RT @TylerDinucci: The image of white teens in “Make America Great Again” hats screaming “build the wall!” at a Native American Vietnam vete…',
#  "RT @calvinstowell: when you have a bunch of white kids screaming 'build the wall' at indigenous folks it's very apparent that 'the wall' ha…",
#  'RT @eedugdale: Crowds gathering in DTLA for the 2019 @womensmarch. Seeing lots of signs referencing President Trump and the wall. @LAist @K…',
#  'RT @houseofdrool: @kurteichenwald $5.3B spent on a wall is giving $5.3B to the Trump 2020 campaign. \nNot border security.\nNot immigration r…',
#  'RT @givings38: @LindseyGrahamSC remember this??? Open up the government so people can go back to work! Stop holding that stupid wall over t…',
#  'RT @TheRISEofROD: China plans $1 Trillion buying spree to reduce trade deficit...\n\nPresident @realDonaldTrump needs to declare National Eme…',
#  'RT @BlueGhost40_: Trump is running television ads to ask people to call 800-350-6647 and press 1 to DEMAND that Pelosi and Schumer fund the…',
#  'RT @realDonaldTrump: Mexico is doing NOTHING to stop the Caravan which is now fully formed and heading to the United States. We stopped the…',
#  "RT @kharyp: Shep Smith: “There’s no tango here. The president said I’m ‘shutting the government down,'”  \n\nRepublicans had total government…",
#  'RT @FiveRights: Simplest issue ever.\nIf you care abt Americans, you want the wall.\nIf you care abt something else more, like importing Dem…',
#  "@NateSilver538 Fully funding the wall would cost at least $50 billion, but it would take far longer than Trump's presidency to build, so maybe starting it in exchange for a bill guaranteeing democracy would be a price worth paying, if that's possible.",
#  'RT @Harlan: 🚨🚨🚨\n\nPBS-NPR-Marist poll:\n\n51% of Latino adults “strongly approve” or “approve” of the job @realDonaldTrump is doing.\n\nTrump wa…',
#  'RT @evansiegfried: DACA for the wall isn’t going over well with some https://t.co/8u4BsjDLVR',
#  'RT @realDonaldTrump: Mexico is doing NOTHING to stop the Caravan which is now fully formed and heading to the United States. We stopped the…',
#  'RT @squaresense: This is why “the wall” can’t be built under almost any circumstance. These little racist kids were chanting it at a *Nativ…',
#  'RT @politvidchannel: Republican Rep. Will Hurd Who is The only GOP member representing a district along the southern border on Trump’s Bord…',
#  'RT @funder: BREAKING: Trump plans to propose extending DACA &amp; TPS status for a limited time this afternoon in exchange for wall funding &amp; r…',
#  '@realDonaldTrump Thank you for trying to protect American citizens! WE DO WANT THE WALL!! We need the wall!!  What planet are liberals on? They are wanting illegals in because they will vote for them in 2020. That is the Real reason.',
#  'RT @mrs_pinky85: Lib: Who paying for the Wall?\n\nMe: Who paying for all the stuff yall want? 😳',
#  'RT @RealOmarNavarro: Declaring an Emergency to Build a Border Wall a great way to get the job done. Let’s build that wall. The true art of…',
#  'RT @AdamParkhomenko: Trump will make a major announcement. It will be racist as hell &amp; intended to scare the ever loving shit out of old pe…',
#  "RT @NateSilver538: Maybe Pelosi should offer to fully fund the border wall in exchange for passage of HR 1, the Democrats' giant voting rig…",
#  'RT @StormIsUponUs: While the military prepares to build a wall that Nancy Pelosi hates so much she is prepared to shut down the government…',
#  'RT @funder: BREAKING: Trump plans to propose extending DACA &amp; TPS status for a limited time this afternoon in exchange for wall funding &amp; r…',
#  '@davidaxelrod If so, the good news is: DACA...now; years for wall (which can be changed, just let trump changed that Obama did)',
#  'RT @TomFitton: .@RealDonaldTrump to offer a massive amnesty in exchange for a portion of the Wall? \n https://t.co/voF2TlgM66',
#  'RT @voiceofnigeria: #2019Debate\nTo secure our borders, Fela Durotoye of the ANN says “we shall invest in technology like drone technology.…',
#  "DON'T GIVE IN! STAND TALL! BUILD THE WALL!💪🇺🇸🦅 https://t.co/Bcoy0sqU4z",
#  '2/ {"...to hear me RANT about how GREAT I AM and how shitty YOU are! And\n\nto RANT about the STATE-OF-OUR-UNION being a complete DUMPSTER FIRE!\n\nOH! About MY \'ShitDownSHUTDOWN\'??\n\nI am willing to ACCEPT \n\nNancy &amp; Chuck\'s $25BILLION$ offer for my WALL for DACA citizenship!\n#KINGMe https://t.co/hakjbzgPHb',
#  'RT @realDonaldTrump: Mexico is doing NOTHING to stop the Caravan which is now fully formed and heading to the United States. We stopped the…',
#  'RT @JDRucker: Declaring a national emergency to #FundTheWall will instantly be stalled by legal challenges and wrapped in bureaucratic red…',
#  'RT @SarahPalinUSA: Report: Drug Smugglers Brought 700LBS Of Cocaine Across The Border In Area Without Wall https://t.co/Gh1NoJHJdT',
#  'RT @GeoffRBennett: NEW: The Democratic prebuttal to Trump\'s shutdown-related speech: \n- "This is not a compromise as it includes the same w…',
#  "RT @calvinstowell: when you have a bunch of white kids screaming 'build the wall' at indigenous folks it's very apparent that 'the wall' ha…",
#  'RT @katya_zamo: Fund the wall before these razors turn my nephew gay',
#  'The Dems should offer a compromise. They should promise to match Mexico’s spending on “the wall” dollar for dollar if “he” opens up the government. #ShutdownCompromise #AsPoliticalAsIgetonTwitter',
#  'RT @johnpavlovitz: .@realDonaldTrump the vast majority of the country doesn’t want this wall. They want you to stop holding the Government…',
#  "RT @pacelattin: Trump says San Antonio is an example of a city where a border wall has worked. \n\nSan Antonio isn't on the border.  Nor has…",
#  'RT @JDRucker: Declaring a national emergency to #FundTheWall will instantly be stalled by legal challenges and wrapped in bureaucratic red…',
#  '@realDonaldTrump Are you going to tell us Who are these everybody wants a wall NO not everybody NO not everyone says walls work. So you want a Permanent wall, yet offering a Temporary DACA deal that the courts already  protect? Very one sided. Open gov, then sit down and work out border security',
#  "RT @PatriotRocker69: Nancy Pelosi's Previous Taxpayer Funded Trips Were Pretty Fancy\n\nApparently hypocrite @SpeakerPelosi lives it up prett…",
#  '@BillKristol Scott Dworkin  BREAKING: Trump plans to propose extending DACA &amp; TPS status for a limited time this afternoon in exchange for wall funding &amp; reopening the government. Weak. He’s trying to use even more Americans to get his wall. This is disgusting. No deal. No wall.',
#  "RT @ScottPresler: President Trump could offer the democrats everything they want &amp; Pelosi still wouldn't give Trump $ for the wall. \n\nWith…",
#  '@AMike4761 By the way you have a wall tear it down so you can be more dignified',
#  'RT @TylerDinucci: The image of white teens in “Make America Great Again” hats screaming “build the wall!” at a Native American Vietnam vete…',
#  'RT @kurteichenwald: If trump does offer to allow the dreamers to stay in the only country they have ever known in exchange for money for hi…',
#  'RT @DemWrite: A GOP Congressman from Texas is calling the “crisis” at the border a “myth”, and Trump’s wall “ancient”.\nhttps://t.co/WiMq762…',
#  'RT @adamcbest: @realDonaldTrump If you are trying to trade DACA for the wall the Democrats’ answer is no. The Supreme Court isn’t ruling on…',
#  "@CongPalazzo Oh look, another complicit Republican congressman. Sycophants for Trump distorting facts to justify trumps Trump 's ignorant useless racist wall. Whatta surprise. Keep supporting the dicktraitor and you'll be on the bread lines too",
#  'RT @realDonaldTrump: Mexico is doing NOTHING to stop the Caravan which is now fully formed and heading to the United States. We stopped the…',
#  'RT @funder: BREAKING: Trump plans to propose extending DACA &amp; TPS status for a limited time this afternoon in exchange for wall funding &amp; r…',
#  'RT @gregpak: No. The wall is unacceptable in and of itself, for environmental, security-related, economic, social, and moral reasons. Never…',
#  'RT @realDonaldTrump: Mexico is doing NOTHING to stop the Caravan which is now fully formed and heading to the United States. We stopped the…',
#  "@OSleisure @Splodz Celebrating turning 40 with #walk1000miles and planning on doing the Coleridge Way and Hadrian's wall as part of my 1000!",
#  "RT @calvinstowell: when you have a bunch of white kids screaming 'build the wall' at indigenous folks it's very apparent that 'the wall' ha…",
#  'RT @Gunitastronaut: The irony of those hats is absolutely  insane. If only American Indians had built “the wall” 🤔 https://t.co/OBqShWl3cM',
#  "If you have any doubts still at resolve or Democrats to reject any resolution of the Shutdown, watch their reaction to Trump's offer today.\n\nA million illegals given extra protections for $5.7 billion wall funding.\n\nIf Democrats CARED about #Dreamers they'd jump at this.\n\n#tcot"]

# %%
tweet_df = pd.DataFrame({"Created at": created_at,
                         "Screen name": screen_name,
                         "User name": user_name,
                         "Tweet": full_text,
                         "Favorite count": favorite_count,
                         "Hashtags": hashtags
                        })

print(f"Total tweets: {len(tweet_df)}")
# Out:
# Total tweets: 891

# %%
tweet_df.head(20)
# Out:
#                   Created at      Screen name              User name  \
# 0  2019-01-19 19:18:00+00:00       FoodGnomes            Food Gnomes
# 1  2019-01-19 19:17:56+00:00          hcheryl            cheryl h 🇺🇸
# 2  2019-01-19 19:17:41+00:00  marymar28207884           marymargaret
# 3  2019-01-19 19:17:39+00:00       JAbernatha       Jeremy Abernatha
# 4  2019-01-19 19:17:29+00:00    MonaRCastillo          Mona Castillo
# 5  2019-01-19 19:17:27+00:00        ltrllyddy        Literally Daddy
# 6  2019-01-19 19:17:25+00:00         pj6969pj                    PJP
# 7  2019-01-19 19:17:24+00:00        rev_ellis       Rev. W. H. Ellis
# 8  2019-01-19 19:17:11+00:00   paulbeardsley_              Ραυℓιαи 🖤
# 9  2019-01-19 19:17:11+00:00         pj6969pj                    PJP
# 10 2019-01-19 19:17:02+00:00       Mannyotiko            Manny Otiko
# 11 2019-01-19 19:17:01+00:00         pj6969pj                    PJP
# 12 2019-01-19 19:16:55+00:00       Denlewis01       Den Lewis ⭐️⭐️⭐️
# 13 2019-01-19 19:16:38+00:00     gringene_bio  David Eccles (Māo/32)
# 14 2019-01-19 19:16:36+00:00         pj6969pj                    PJP
# 15 2019-01-19 19:16:29+00:00         pj6969pj                    PJP
# 16 2019-01-19 19:16:25+00:00   paulbeardsley_              Ραυℓιαи 🖤
# 17 2019-01-19 19:16:18+00:00  JoyBell75174267               Joy Bell
# 18 2019-01-19 19:16:16+00:00            Nunni              Nunni ⭐⭐⭐
# 19 2019-01-19 19:16:08+00:00  marymar28207884           marymargaret
#
#                                                 Tweet  Favorite count  \
# 0   #FYI - #ChefsForFeds is looking to expand thei...               0
# 1   RT @SiriusXMPatriot: Missed @DonaldJTrumpJr 's...               0
# 2   RT @BLUEPRINT_Q: 1 - A short #GovernmentShutdo...               0
# 3   RT @pollsofpolitics: Should @POTUS  @realDonal...               0
# 4   @realDonaldTrump It’s already crashing with yo...               1
# 5   Literally make my government shut down, DADDY ...               0
# 6   #PUTIN'S #GOP WANTED #TRAITORTRUMP #FACISM RUN...               1
# 7   #realDonaldTrump the #Egyptian #pharaoh cried ...               0
# 8   RT @waywarddrift: Reducing our dependence on t...               0
# 9   #PUTIN'S #GOP WANTED #TRAITORTRUMP #FACISM RUN...               1
# 10  RT @pj6969pj: #PUTIN'S #GOP WANTED #TRAITORTRU...               0
# 11  #PUTIN'S #GOP WANTED #TRAITORTRUMP #FACISM RUN...               1
# 12  RT @gbroh10: Stand Your Ground #POTUS #Governm...               0
# 13  RT @sciencemagazine: The partial #GovernmentSh...               0
# 14  #PUTIN'S #GOP WANTED #TRAITORTRUMP #FACISM RUN...               1
# 15  #PUTIN'S #GOP WANTED #TRAITORTRUMP #FACISM RUN...               1
# 16  RT @skiefer11: The #GovernmentShutdown is now ...               0
# 17  RT @gbroh10: Stand Your Ground #POTUS #Governm...               0
# 18  RT @threadreaderapp: @JenniferEvette6 Bonjour ...               0
# 19  RT @BLUEPRINT_Q: 12 - This concludes my short ...               0
#
#                                              Hashtags
# 0   [{'text': 'FYI', 'indices': [0, 4]}, {'text': ...
# 1   [{'text': 'BuzzFeedNews', 'indices': [102, 115...
# 2   [{'text': 'GovernmentShutdown', 'indices': [29...
# 3   [{'text': 'GovernmentShutdown', 'indices': [62...
# 4   [{'text': 'GovernmentShutdown', 'indices': [61...
# 5   [{'text': 'GovernmentShutdown', 'indices': [50...
# 6   [{'text': 'PUTIN', 'indices': [0, 6]}, {'text'...
# 7   [{'text': 'realDonaldTrump', 'indices': [0, 16...
# 8                                                  []
# 9   [{'text': 'PUTIN', 'indices': [0, 6]}, {'text'...
# 10  [{'text': 'PUTIN', 'indices': [14, 20]}, {'tex...
# 11  [{'text': 'PUTIN', 'indices': [0, 6]}, {'text'...
# 12  [{'text': 'POTUS', 'indices': [31, 37]}, {'tex...
# 13  [{'text': 'GovernmentShutdown', 'indices': [33...
# 14  [{'text': 'PUTIN', 'indices': [0, 6]}, {'text'...
# 15  [{'text': 'PUTIN', 'indices': [0, 6]}, {'text'...
# 16  [{'text': 'GovernmentShutdown', 'indices': [19...
# 17  [{'text': 'POTUS', 'indices': [31, 37]}, {'tex...
# 18                                                 []
# 19  [{'text': 'GovernmentShutdown', 'indices': [46...

# %% [markdown]
# # Sentiment Analysis of Shutdown Full_Tweets
# compound is the sum of the valence scores of each word in the input.
# A valence score is a number indicating both positivity/negativity and intensity.
# The pos, neu and neg scores are ratios describing the proportion of the input text that falls into each category.

# %%
# Variables for holding sentiments
compound_list = []
positive_list = []
negative_list = []
neutral_list = []
full_text_list = []

# %%
# Loop through all tweets
#for tweet in target_string:
for tweet in full_text:    

        # Run Vader Analysis on each tweet
        #results = analyzer.polarity_scores(tweet["full_text"])
        #results = analyzer.polarity_scores(target_string)
        results = analyzer.polarity_scores(tweet)
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        #print(full_text)

        # Add each value to the appropriate list
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        full_text_list.append(tweet)

# %%
# Print Analysis - Analysis of one tweet at a time
#print(tweet)
#print("Compound Score:", compound)
#print("Positive Score:", pos)
#print("Neutral Score:", neu)
#print("Negative Score: ", neg)


senti_df = pd.DataFrame({"Tweet":full_text_list,
                        "Compound":compound_list,
                        "Positive":positive_list,
                        "Neutral":neutral_list,
                        "Negative":negative_list})

senti_df.head()

senti_df.to_csv('sentiment.csv')

# %%
# Print the Averages - An average of all tweets
#print(f"User: {tweet}")
print(f"Compound: {np.mean(compound_list):.3f}")
print(f"Positive: {np.mean(positive_list):.3f}")
print(f"Neutral: {np.mean(neutral_list):.3f}")
print(f"Negative: {np.mean(negative_list):.3f}")
# Out:
# Compound: 0.001
# Positive: 0.062
# Neutral: 0.875
# Negative: 0.063

# %% [markdown]
# # Search Other Tweet Terms with User Inputs

# %%
def runSentiment(search_term):
    
    tweet_created_at = []
    tweet_text = []
    tweet_user = []
    search_term_list = []

    # Search for all tweets using a Cursor
    # tweet_mode='extended' allows for you to get tweets beyond the 140 character limit
    public_tweets = tweepy.Cursor(api.search,
                                tweet_mode='extended',
                                q=search_term,
                                result_type="recent",
                                include_entities=True,
                                lang="en").items(20)
    
    for tweet in public_tweets:
        tweet_created_at.append(tweet.created_at)
        tweet_text.append(tweet.full_text)
        tweet_user.append(tweet.user.name)
    
    tweet_df = pd.DataFrame({"User": tweet_user, "Tweet Date":tweet_created_at, "Tweet":tweet_text})
    
    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []
    full_text_list = []
    
    # Loop through all tweets
    #for tweet in target_string:
    for tweet in tweet_text:    

        # Run Vader Analysis on each tweet
        #results = analyzer.polarity_scores(tweet["full_text"])
        #results = analyzer.polarity_scores(target_string)
        results = analyzer.polarity_scores(tweet)
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        #print(full_text)

        # Add each value to the appropriate list
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        full_text_list.append(tweet)
        search_term_list.append(search_term)
        
    # Create DataFrame for Tweet Sentiments
    
    senti_df = pd.DataFrame({"Search Term":search_term_list,
                            "Tweet":full_text_list,
                            "Positive Score":positive_list,
                            "Neutral Score":neutral_list,
                            "Negative Score":negative_list,
                            "Compound Score":compound_list})
    
    return(senti_df)

# %%
pd.set_option('display.max_colwidth', -1)

# Search Term
search_term = input("Which term would you like to search for? ")

senti_df = runSentiment(search_term)

senti_df.head(50)
# Out:
# Which term would you like to search for? Republican's Fault
#            Search Term  \
# 0   Republican's Fault
# 1   Republican's Fault
# 2   Republican's Fault
# 3   Republican's Fault
# 4   Republican's Fault
# 5   Republican's Fault
# 6   Republican's Fault
# 7   Republican's Fault
# 8   Republican's Fault
# 9   Republican's Fault
# 10  Republican's Fault
# 11  Republican's Fault
# 12  Republican's Fault
# 13  Republican's Fault
# 14  Republican's Fault
# 15  Republican's Fault
# 16  Republican's Fault
# 17  Republican's Fault
# 18  Republican's Fault
# 19  Republican's Fault
#
#                                                                                                                                                                                                                                                                                                                  Tweet  \
# 0   @fortress112 @GodFirstGina @SpeakerPelosi @realDonaldTrump Well one Dem family member just informed me he is changing registrations to Republican because the Dems are now Socialists. That’s the good news. Bad news he still think shutdown is Trump’s fault ☹️
# 1   @george_capen I vote, and never for a republican. It’s not my fault.
# 2   RT @Anselmo4House: I thought it was suburban Republican‘s fault that a background check bill couldn’t happen? \n\nMN expanded background chec…
# 3   RT @Anselmo4House: I thought it was suburban Republican‘s fault that a background check bill couldn’t happen? \n\nMN expanded background chec…
# 4   I thought it was suburban Republican‘s fault that a background check bill couldn’t happen? \n\nMN expanded background check obstacle: Top Democrat. https://t.co/w5ZwYoEsN6
# 5   Kamala: “I’m California’s top cop.”\n🦗🦗🦗\nLeftists: Kamala is a cop.\nneo-liberals: THAT’S SO RACIST, YOU ARE RACIST, AND SEXIST, AND A REPUBLICAN PLANT, AND A TERRORIST, AND IT’S YOUR FAULT HILLARY LOST.
# 6   the fault squarely lies with\nthe Republican.If you don’t \nwant this happening again vote for D’s for all Dem representation in both the Senate,&amp; House in 2020.\n2/ https://t.co/9cf6G1PRKg
# 7   RT @TheRealPatriot1: Actually I’m still a registered Republican. I’m the opposite of tolerant. I hate you people. It’s not tRump’s fault; h…
# 8   @davidfrum Were you ON this while you were still a Republican?  What were your public statements about carbon while you worked for George W. Bush?  Don't mean to pile on you specifically, but it's the fault of Republicans from Reagan times that we are where we are today.
# 9   Actually I’m still a registered Republican. I’m the opposite of tolerant. I hate you people. It’s not tRump’s fault; he’s just a reality show host. It’s you scum that voted him in along with Russia’s help that got us into this mess. I hope you go to hell soon. https://t.co/LDhbN2m67m
# 10  RT @junderscorew: I love how in 2014 when the government shit down it was congresses fault because the Congress was majority republican now…
# 11  @SenatorLankford   Senator , why are you in such ANGUISH over the Border Wall Shutdown . As a 3rd generation Republican , I can just say it is NOT our party's fault and we really don't need to be acting  guilty over it .
# 12  @lxlNarakulxl @MAG091365 @PressSec @realDonaldTrump Typical republican, it’s everyone else’s fault! Trump owns it! He spewed it all over national tv!
# 13  the fault squarely lies with\nthe Republican.If you don’t \nwant this happening again vote for D’s for all Dem representation in both the Senate,&amp; House in 2020.\n2/
# 14  I love how in 2014 when the government shit down it was congresses fault because the Congress was majority republican now in 2019 it’s the presidents fault because he’s republican and Congress is majority democrat lol https://t.co/QJaPSophgv
# 15  RT @JanineMaverick: @WhitneyJalea @iamcardib It's almost like we have a pres. who is rich but may be cash poor &amp; trying to increase his wea…
# 16  @GuilfoyleJJ Of course. Every bad decision a Republican makes is the fault of democrats.\n\nIt had nothing at all to do with the massive debt Reagan left us. And before you try to claim b.s. on that statement, read Reagan's final speech to America in which he says his biggest regret is the
# 17  @julsbreakey @DLong4NCSenate @LeffelHeather @Nappy_Snitter @SpeakerPelosi @realDonaldTrump They needed 60 votes and there was not enough Republicans... they needed votes from freaking Dems ...and we all know that wasn't going to happen! But yeah, it's all Republican's fault..smdh
# 18  RT @SassyKadiK: @realDonaldTrump @JimInhofe The fact, more Americans believe it is your fault and you refuse to listen to We the People.\nDo…
# 19  @WhitneyJalea @iamcardib It's almost like we have a pres. who is rich but may be cash poor &amp; trying to increase his wealth. By 2026 many people (53% of us) will see an increase as a result of the Republican tax overhaul but it's probably going to be made to look like the fault of whoever is in office.
#
#     Positive Score  Neutral Score  Negative Score  Compound Score
# 0   0.105           0.714          0.181          -0.5574
# 1   0.201           0.799          0.000           0.3089
# 2   0.000           0.863          0.137          -0.4019
# 3   0.000           0.863          0.137          -0.4019
# 4   0.075           0.708          0.217          -0.5267
# 5   0.035           0.465          0.500          -0.9818
# 6   0.040           0.793          0.168          -0.6369
# 7   0.174           0.678          0.148          -0.0880
# 8   0.000           0.922          0.078          -0.6007
# 9   0.166           0.649          0.186          -0.4968
# 10  0.142           0.644          0.214          -0.2732
# 11  0.052           0.778          0.170          -0.7331
# 12  0.000           0.842          0.158          -0.5538
# 13  0.041           0.786          0.173          -0.6369
# 14  0.149           0.660          0.191          -0.2500
# 15  0.187           0.673          0.140          -0.1522
# 16  0.000           0.807          0.193          -0.8885
# 17  0.077           0.875          0.048           0.2942
# 18  0.000           0.811          0.189          -0.5994
# 19  0.216           0.678          0.106           0.7108

# %%
term_df = senti_df.groupby("Search Term")

term_df.mean()
# Out:
#                     Positive Score  Neutral Score  Negative Score  \
# Search Term
# Republican's Fault  0.083           0.7504         0.1667
#
#                     Compound Score
# Search Term
# Republican's Fault -0.373265
